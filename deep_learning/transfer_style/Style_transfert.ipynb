# %% [markdown]
# ## Overview
# N'hésitez pas à faire ce TP sous google collab pour des calculs plus rapides
#
# Le transfert de style, c'est :
# - prendre une image source :
# <img src="https://github.com/tensorflow/models/blob/master/research/nst_blogpost/Green_Sea_Turtle_grazing_seagrass.jpg?raw=1" alt="Drawing" style="width: 100px;"/>
#
#
# - prendre une image avec un certain 'style' :
# <img src="https://github.com/tensorflow/models/blob/master/research/nst_blogpost/The_Great_Wave_off_Kanagawa.jpg?raw=1" alt="Drawing" style="width: 100px;"/>
#
#
# - transformer l'image source en lui appliquant le 'style' de la seconde image :
# <img src="https://github.com/tensorflow/models/blob/master/research/nst_blogpost/wave_turtle.png?raw=1" alt="Drawing" style="width: 100px;"/>
#
# Dans ce TP, nous allons   :
# - définir deux notions deux distance entre images, une distance de "style" $L_{style}$, et une distance de "contenu" $L_{content}$.
# - puis trouver (générer) l'image qui minimise au mieux la distance de "contenu" avec l'image source, tout en minimisant la distance de "style" avec l'image de style.

# %% [markdown]
# # Import et chargement des images

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import vgg19
import os

os.makedirs("./out", exist_ok=True)
content_path = './Green_Sea_Turtle_grazing_seagrass.jpg'
style_path = './The_Great_Wave_off_Kanagawa.jpg'

# Dimensions of the generated picture.
width, height = keras.preprocessing.image.load_img(content_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)

# %% [markdown]
# - Comme nous allons appliquer vgg19 pour obtenir des features de l'image, il va nous falloir appliquer le preprocessing qu'il attend pour que l'entrée soit bien de la bonne forme :

# %%
def preprocess_image(image_path):
    # Util function to open, resize and format pictures into appropriate tensors
    img = keras.preprocessing.image.load_img(
        image_path, target_size=(img_nrows, img_ncols)
    )
    img = keras.preprocessing.image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return tf.convert_to_tensor(img)

# %% [markdown]
# - Pour visualiser l'image que nous allons générer, il nous faudra faire l'inverse de tout le preprocessing de vgg19, pour que celle-ci se retrouve bien au format que sait afficher.
#     - on redonne la forme normale d'une image (nb_line, nb_colonne, 3)
#     - on de-normalize
#     - on ramene en rgb
#     - on ramene les pixel en uint8

# %%
def deprocess_image(x):
    # Util function to convert a tensor into a valid image
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype("uint8")
    return x

# %% [markdown]
# # 2- Les metrique de distance

# %% [markdown]
# Comment faire une différence de contenu et de style ?
# La réponse est proche de ce que nous avons vu en transfert learning:
# - les valeurs des dernieres couches de convolutions, qui contiennent des concepts plus complexes, seront similaires sur des images ayant le même contenu
# - le "style" d'une image peut être retrouvé par la présence d'éléments (couleurs, coups de pinceau, variations de pixels) souvent présent simultanéments sur une images. Les valeurs des couches proches de l'entrée et celles intermedaire auront des combinaisons similaires sur des images de mêmes styles
#
# <img src="https://miro.medium.com/max/724/0*E6BE6GDv-53smX0B.jpg" alt="Drawing" style="width: 500px;"/>

# %%
vgg = tf.keras.applications.vgg19.VGG19(include_top=False, weights='imagenet')
vgg.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
# List of layers to use for the style loss.
style_layer_names = [
    "block1_conv1",
    "block2_conv1",
    "block3_conv1",
    "block4_conv1",
    "block5_conv1",
]
# The layer to use for the content loss.
content_layer_name = "block5_conv2"

# %% [markdown]
# - la distance de contenu peut-être simplement définie comme la difference pixel à pixel entre deux image
#     - tf.square(A-B) permet de mesure la différence (au carré) pixel a pixel entre A et B
#     - tf.reduce_sum permet d'obtenir la difference totale, i.e. la somme des différence entre chaque pixels de A et B

# %%
def content_loss(base, combination):
    return tf.reduce_sum(tf.square(combination - base))

# %% [markdown]
# - la matrice de gram est une matrice permettant de mesurer les correlations entre les features calculées par une couche
#     - c = dimension des channels (features)
#     - h*w = toutes les valeurs dans les différentes zones de l'image que peut prendre la feature
#
# <img src="https://datascience-enthusiast.com/figures/NST_GM.png" alt="gram" style="width: 500px;"/>
# source : https://datascience-enthusiast.com/DL/Art_Generation_with_Neural_Style_Transfer_v2.html

# %%
def gram_matrix(x):
    x = tf.transpose(x, (2, 0, 1))
    features = tf.reshape(x, (tf.shape(x)[0], -1)) # concatene les valeurs que peuvent prendre chacune des features
    gram = tf.matmul(features, tf.transpose(features))
    return gram

# %% [markdown]
# - La loss de style est ainsi la différence entre les matrixes de gram de style et combination calculée comme la précédente
#     - calculer cette loss comme la loss précédente appliquée sur les matrices de gram de style et combination
#     - entre pratique, elle est normalisée en divisant par un facteur dépendant de la taille de l'entrée :
#
#             (4.0 * (channels ** 2) * (img_nrows * img_ncols ** 2))

# %%
width, height = keras.preprocessing.image.load_img(content_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)


def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return tf.reduce_sum(tf.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %% [markdown]
# - Pour que ça marche mieux, on a besoin d'une troisieme loss, dont le but est de garder l'image générée localement cohérente (avec en moyenne peu de variation entre deux pixels proches)
#     - elle mesure les différences entre pixels adjacent sur la même ligne (a) et adjacents sur la même colonne colonne (b)
#     - puis calcule la somme de cette erreur

# %%
def total_variation_loss(x):
    a = tf.square(x[:, :img_nrows-1, :img_ncols-1, :] - x[:, 1:, :img_ncols-1, :])
    b = tf.square(x[:, :img_nrows-1, :img_ncols-1, :] - x[:, :img_nrows -1, 1:, :])
    return tf.reduce_sum(tf.pow(a + b, 1.25))

# %% [markdown]
# # Créer et entrainer notre "modele"

# %% [markdown]
# - charger la partie extraction de feature de vgg19 comme nous l'avions fait dans le tp transfert learning
#     - rappel : weights="imagenet", include_top=False

# %%
model = vgg19.VGG19(weights="imagenet", include_top=False)

# %% [markdown]
# - Recupere le nom et sortie de tout les layers de vgg19, et crée un modèle les retournant tous, que l'on puisse calculer notre loss à partir de nimporte quelle couche

# %%
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
feature_extractor = keras.Model(inputs=model.inputs, outputs=outputs_dict)

# %% [markdown]
# - notre fonction de loss finale :
#     - batches les 3 images en entrée
#     - applique une extraction des feature de vgg sur ces 3 images
#         - ça va plus vite que de le faire 1 par 1
#     - recupere les valeurs des features map necessaires et calcule la loss totales en additionnant celles-ci

# %%
# Pondération des différentes loss
total_variation_weight = 1e-6
style_weight = 1e-6
content_weight = 2.5e-8

def compute_loss(combination_image, base_image, style_reference_image):
    input_tensor = tf.concat(
        [base_image, style_reference_image, combination_image], axis=0
    )
    features = feature_extractor(input_tensor)

    # Initialize the loss
    loss = tf.zeros(shape=())

    # Ajoute la content loss
    layer_features = features[content_layer_name]
    base_image_features = layer_features[0, :, :, :]
    combination_features = layer_features[2, :, :, :]
    loss += content_weight * content_loss(
        base_image_features, combination_features
    )
    
    # Ajoute la style loss : somme de la loss de style pour chaqun 
    for layer_name in style_layer_names:
        layer_features = features[layer_name]
        style_reference_features = layer_features[1, :, :, :]
        combination_features = layer_features[2, :, :, :]
        sl = style_loss(style_reference_features, combination_features)
        loss += (style_weight / len(style_layer_names)) * sl

    # Add la total variation loss
    loss += total_variation_weight * total_variation_loss(combination_image)
    return loss

# %% [markdown]
# - calcule les gradients de l'erreur

# %%
@tf.function
def compute_loss_and_grads(combination_image, base_image, style_reference_image):
    with tf.GradientTape() as tape:
        loss = compute_loss(combination_image, base_image, style_reference_image)
    grads = tape.gradient(loss, combination_image)
    return loss, grads

# %% [markdown]
# - choisi l'optimiser, qui va nous servir à pour minimiser ces gradients.
#     - mes parametres : SGD avec exponential decay, i.e diminution du taux d'apprentissage au cours du temps : initial_learning_rate=100.0, decay_steps=100, decay_rate=0.96
#         - keras.optimizers.SGD(keras.optimizers.schedules.ExponentialDecay(...))
#     - le learning rate peut être très fort car on travaille que sur une seule "couche" : l'image que l'on veut générer

# %%
optimizer = keras.optimizers.SGD(
    keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=100.0, decay_steps=100, decay_rate=0.96
    )
)

# %% [markdown]
# - chargeons notre image de contenu, image de style et initialisons l'image que nous allons générée
#     - pour accelerer l'entrainement, l'image que nous allons générée est initialisée à partir de l'image de contenu

# %%
base_image = preprocess_image(content_path)
style_reference_image = preprocess_image(style_path)
combination_image = tf.Variable(preprocess_image(content_path))

# %% [markdown]
# # On est enfin parti !

# %% [markdown]
# - On est parti !
# - Les images intermediaires sont sauvegardées dans le dossier "./out", que vous puissiez visualiser l'avancement

# %%
iterations = 1000
for i in range(1, iterations + 1):
    loss, grads = compute_loss_and_grads(
        combination_image, base_image, style_reference_image
    )
    # calcule la nouvelle valeur de notre image générée a partir des gradients de l'erreur, pour que celle-ci mene à une erreur plus petite
    optimizer.apply_gradients([(grads, combination_image)])
    if i % 1 == 0:
        print("Iteration %d: loss=%.2f" % (i, loss))
        img = deprocess_image(combination_image.numpy())
        fname = "_at_iteration_%d.png" % i
        keras.preprocessing.image.save_img(os.path.join("./out",fname), img)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function compute_loss at 0x0000023D8D8D49D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function compute_loss at 0x0000023D8D8D49D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Iteration 1: loss=160100.20
# Iteration 2: loss=123223.02
# Iteration 3: loss=78976.93
# Iteration 4: loss=59035.00
# Iteration 5: loss=48621.62
# Iteration 6: loss=43871.79
# Iteration 7: loss=43129.62
# Iteration 8: loss=39021.86
# Iteration 9: loss=38081.81
# Iteration 10: loss=32747.04
# Iteration 11: loss=30923.53
# Iteration 12: loss=28485.93
# Iteration 13: loss=27032.87
# Iteration 14: loss=25661.67
# Iteration 15: loss=24621.55
# Iteration 16: loss=23687.21
# Iteration 17: loss=22891.10
# Iteration 18: loss=22165.58
# Iteration 19: loss=21521.58
# Iteration 20: loss=20935.48
# Iteration 21: loss=20402.43
# Iteration 22: loss=19914.60
# Iteration 23: loss=19464.63
# Iteration 24: loss=19047.86
# Iteration 25: loss=18661.24
# Iteration 26: loss=18301.29
# Iteration 27: loss=17964.51
# Iteration 28: loss=17649.59
# Iteration 29: loss=17353.31
# Iteration 30: loss=17075.00
# Iteration 31: loss=16812.59
# Iteration 32: loss=16565.89
# Iteration 33: loss=16331.33
# Iteration 34: loss=16109.95
# Iteration 35: loss=15899.31
# Iteration 36: loss=15699.54
# Iteration 37: loss=15508.84
# Iteration 38: loss=15327.52
# Iteration 39: loss=15153.97
# Iteration 40: loss=14988.18
# Iteration 41: loss=14829.23
# Iteration 42: loss=14676.88
# Iteration 43: loss=14530.68
# Iteration 44: loss=14390.22
# Iteration 45: loss=14255.35
# Iteration 46: loss=14125.56
# Iteration 47: loss=14000.94
# Iteration 48: loss=13880.77
# Iteration 49: loss=13765.04
# Iteration 50: loss=13652.87
# Iteration 51: loss=13544.58
# Iteration 52: loss=13440.02
# Iteration 53: loss=13338.88
# Iteration 54: loss=13240.78
# Iteration 55: loss=13145.94
# Iteration 56: loss=13053.70
# Iteration 57: loss=12964.26
# Iteration 58: loss=12877.34
# Iteration 59: loss=12793.00
# Iteration 60: loss=12710.95
# Iteration 61: loss=12631.17
# Iteration 62: loss=12553.45
# Iteration 63: loss=12477.77
# Iteration 64: loss=12403.96
# Iteration 65: loss=12332.12
# Iteration 66: loss=12262.14
# Iteration 67: loss=12193.86
# Iteration 68: loss=12127.23
# Iteration 69: loss=12062.15
# Iteration 70: loss=11998.56
# Iteration 71: loss=11936.44
# Iteration 72: loss=11875.76
# Iteration 73: loss=11816.33
# Iteration 74: loss=11758.26
# Iteration 75: loss=11701.40
# Iteration 76: loss=11645.74
# Iteration 77: loss=11591.32
# Iteration 78: loss=11538.11
# Iteration 79: loss=11485.97
# Iteration 80: loss=11434.82
# Iteration 81: loss=11384.67
# Iteration 82: loss=11335.48
# Iteration 83: loss=11287.15
# Iteration 84: loss=11239.81
# Iteration 85: loss=11193.40
# Iteration 86: loss=11147.89
# Iteration 87: loss=11103.27
# Iteration 88: loss=11059.41
# Iteration 89: loss=11016.38
# Iteration 90: loss=10974.15
# Iteration 91: loss=10932.72
# Iteration 92: loss=10892.11
# Iteration 93: loss=10852.21
# Iteration 94: loss=10813.03
# Iteration 95: loss=10774.51
# Iteration 96: loss=10736.68
# Iteration 97: loss=10699.46
# Iteration 98: loss=10662.84
# Iteration 99: loss=10626.84
# Iteration 100: loss=10591.42
# Iteration 101: loss=10556.62
# Iteration 102: loss=10522.25
# Iteration 103: loss=10488.46
# Iteration 104: loss=10455.19
# Iteration 105: loss=10422.42
# Iteration 106: loss=10390.10
# Iteration 107: loss=10358.34
# Iteration 108: loss=10327.08
# Iteration 109: loss=10296.25
# Iteration 110: loss=10265.90
# Iteration 111: loss=10235.99
# Iteration 112: loss=10206.51
# Iteration 113: loss=10177.48
# Iteration 114: loss=10148.84
# Iteration 115: loss=10120.64
# Iteration 116: loss=10092.80
# Iteration 117: loss=10065.38
# Iteration 118: loss=10038.33
# Iteration 119: loss=10011.71
# Iteration 120: loss=9985.39
# Iteration 121: loss=9959.48
# Iteration 122: loss=9933.89
# Iteration 123: loss=9908.66
# Iteration 124: loss=9883.78
# Iteration 125: loss=9859.23
# Iteration 126: loss=9835.01
# Iteration 127: loss=9811.09
# Iteration 128: loss=9787.49
# Iteration 129: loss=9764.23
# Iteration 130: loss=9741.27
# Iteration 131: loss=9718.60
# Iteration 132: loss=9696.21
# Iteration 133: loss=9674.11
# Iteration 134: loss=9652.26
# Iteration 135: loss=9630.67
# Iteration 136: loss=9609.38
# Iteration 137: loss=9588.32
# Iteration 138: loss=9567.51
# Iteration 139: loss=9546.93
# Iteration 140: loss=9526.58
# Iteration 141: loss=9506.47
# Iteration 142: loss=9486.60
# Iteration 143: loss=9466.96
# Iteration 144: loss=9447.59
# Iteration 145: loss=9428.46
# Iteration 146: loss=9409.53
# Iteration 147: loss=9390.82
# Iteration 148: loss=9372.34
# Iteration 149: loss=9354.04
# Iteration 150: loss=9335.95
# Iteration 151: loss=9318.07
# Iteration 152: loss=9300.38
# Iteration 153: loss=9282.87
# Iteration 154: loss=9265.55
# Iteration 155: loss=9248.43
# Iteration 156: loss=9231.50
# Iteration 157: loss=9214.73
# Iteration 158: loss=9198.15
# Iteration 159: loss=9181.75
# Iteration 160: loss=9165.51
# Iteration 161: loss=9149.48
# Iteration 162: loss=9133.58
# Iteration 163: loss=9117.84
# Iteration 164: loss=9102.29
# Iteration 165: loss=9086.89
# Iteration 166: loss=9071.66
# Iteration 167: loss=9056.59
# Iteration 168: loss=9041.69
# Iteration 169: loss=9026.92
# Iteration 170: loss=9012.29
# Iteration 171: loss=8997.82
# Iteration 172: loss=8983.51
# Iteration 173: loss=8969.31
# Iteration 174: loss=8955.27
# Iteration 175: loss=8941.36
# Iteration 176: loss=8927.59
# Iteration 177: loss=8913.96
# Iteration 178: loss=8900.48
# Iteration 179: loss=8887.11
# Iteration 180: loss=8873.87
# Iteration 181: loss=8860.75
# Iteration 182: loss=8847.73
# Iteration 183: loss=8834.85
# Iteration 184: loss=8822.07
# Iteration 185: loss=8809.42
# Iteration 186: loss=8796.89
# Iteration 187: loss=8784.47
# Iteration 188: loss=8772.16
# Iteration 189: loss=8759.96
# Iteration 190: loss=8747.87
# Iteration 191: loss=8735.89
# Iteration 192: loss=8723.99
# Iteration 193: loss=8712.22
# Iteration 194: loss=8700.54
# Iteration 195: loss=8688.97
# Iteration 196: loss=8677.50
# Iteration 197: loss=8666.12
# Iteration 198: loss=8654.83
# Iteration 199: loss=8643.64
# Iteration 200: loss=8632.55
# Iteration 201: loss=8621.55
# Iteration 202: loss=8610.66
# Iteration 203: loss=8599.85
# Iteration 204: loss=8589.12
# Iteration 205: loss=8578.49
# Iteration 206: loss=8567.93
# Iteration 207: loss=8557.46
# Iteration 208: loss=8547.05
# Iteration 209: loss=8536.76
# Iteration 210: loss=8526.53
# Iteration 211: loss=8516.38
# Iteration 212: loss=8506.32
# Iteration 213: loss=8496.34
# Iteration 214: loss=8486.44
# Iteration 215: loss=8476.64
# Iteration 216: loss=8466.92
# Iteration 217: loss=8457.26
# Iteration 218: loss=8447.68
# Iteration 219: loss=8438.18
# Iteration 220: loss=8428.73
# Iteration 221: loss=8419.35
# Iteration 222: loss=8410.05
# Iteration 223: loss=8400.81
# Iteration 224: loss=8391.64
# Iteration 225: loss=8382.53
# Iteration 226: loss=8373.48
# Iteration 227: loss=8364.51
# Iteration 228: loss=8355.62
# Iteration 229: loss=8346.79
# Iteration 230: loss=8338.03
# Iteration 231: loss=8329.32
# Iteration 232: loss=8320.68
# Iteration 233: loss=8312.10
# Iteration 234: loss=8303.56
# Iteration 235: loss=8295.10
# Iteration 236: loss=8286.70
# Iteration 237: loss=8278.37
# Iteration 238: loss=8270.09
# Iteration 239: loss=8261.87
# Iteration 240: loss=8253.70
# Iteration 241: loss=8245.59
# Iteration 242: loss=8237.54
# Iteration 243: loss=8229.54
# Iteration 244: loss=8221.60
# Iteration 245: loss=8213.71
# Iteration 246: loss=8205.88
# Iteration 247: loss=8198.10
# Iteration 248: loss=8190.37
# Iteration 249: loss=8182.70
# Iteration 250: loss=8175.09
# Iteration 251: loss=8167.53
# Iteration 252: loss=8160.01
# Iteration 253: loss=8152.54
# Iteration 254: loss=8145.13
# Iteration 255: loss=8137.76
# Iteration 256: loss=8130.45
# Iteration 257: loss=8123.18
# Iteration 258: loss=8115.95
# Iteration 259: loss=8108.76
# Iteration 260: loss=8101.62
# Iteration 261: loss=8094.52
# Iteration 262: loss=8087.46
# Iteration 263: loss=8080.45
# Iteration 264: loss=8073.48
# Iteration 265: loss=8066.55
# Iteration 266: loss=8059.66
# Iteration 267: loss=8052.81
# Iteration 268: loss=8046.01
# Iteration 269: loss=8039.25
# Iteration 270: loss=8032.54
# Iteration 271: loss=8025.86
# Iteration 272: loss=8019.22
# Iteration 273: loss=8012.63
# Iteration 274: loss=8006.09
# Iteration 275: loss=7999.57
# Iteration 276: loss=7993.11
# Iteration 277: loss=7986.68
# Iteration 278: loss=7980.30
# Iteration 279: loss=7973.94
# Iteration 280: loss=7967.63
# Iteration 281: loss=7961.37
# Iteration 282: loss=7955.12
# Iteration 283: loss=7948.92
# Iteration 284: loss=7942.75
# Iteration 285: loss=7936.62
# Iteration 286: loss=7930.54
# Iteration 287: loss=7924.48
# Iteration 288: loss=7918.45
# Iteration 289: loss=7912.46
# Iteration 290: loss=7906.51
# Iteration 291: loss=7900.58
# Iteration 292: loss=7894.69
# Iteration 293: loss=7888.83
# Iteration 294: loss=7883.00
# Iteration 295: loss=7877.21
# Iteration 296: loss=7871.45
# Iteration 297: loss=7865.72
# Iteration 298: loss=7860.02
# Iteration 299: loss=7854.33
# Iteration 300: loss=7848.69
# Iteration 301: loss=7843.07
# Iteration 302: loss=7837.49
# Iteration 303: loss=7831.93
# Iteration 304: loss=7826.41
# Iteration 305: loss=7820.92
# Iteration 306: loss=7815.46
# Iteration 307: loss=7810.03
# Iteration 308: loss=7804.62
# Iteration 309: loss=7799.25
# Iteration 310: loss=7793.91
# Iteration 311: loss=7788.60
# Iteration 312: loss=7783.31
# Iteration 313: loss=7778.05
# Iteration 314: loss=7772.81
# Iteration 315: loss=7767.60
# Iteration 316: loss=7762.43
# Iteration 317: loss=7757.28
# Iteration 318: loss=7752.14
# Iteration 319: loss=7747.04
# Iteration 320: loss=7741.96
# Iteration 321: loss=7736.91
# Iteration 322: loss=7731.88
# Iteration 323: loss=7726.88
# Iteration 324: loss=7721.90
# Iteration 325: loss=7716.94
# Iteration 326: loss=7712.00
# Iteration 327: loss=7707.09
# Iteration 328: loss=7702.21
# Iteration 329: loss=7697.35
# Iteration 330: loss=7692.52
# Iteration 331: loss=7687.71
# Iteration 332: loss=7682.93
# Iteration 333: loss=7678.18
# Iteration 334: loss=7673.44
# Iteration 335: loss=7668.73
# Iteration 336: loss=7664.04
# Iteration 337: loss=7659.37
# Iteration 338: loss=7654.72
# Iteration 339: loss=7650.10
# Iteration 340: loss=7645.50
# Iteration 341: loss=7640.91
# Iteration 342: loss=7636.35
# Iteration 343: loss=7631.81
# Iteration 344: loss=7627.28
# Iteration 345: loss=7622.77
# Iteration 346: loss=7618.29
# Iteration 347: loss=7613.83
# Iteration 348: loss=7609.38
# Iteration 349: loss=7604.96
# Iteration 350: loss=7600.57
# Iteration 351: loss=7596.18
# Iteration 352: loss=7591.83
# Iteration 353: loss=7587.49
# Iteration 354: loss=7583.17
# Iteration 355: loss=7578.87
# Iteration 356: loss=7574.59
# Iteration 357: loss=7570.33
# Iteration 358: loss=7566.09
# Iteration 359: loss=7561.88
# Iteration 360: loss=7557.68
# Iteration 361: loss=7553.50
# Iteration 362: loss=7549.34
# Iteration 363: loss=7545.19
# Iteration 364: loss=7541.07
# Iteration 365: loss=7536.96
# Iteration 366: loss=7532.87
# Iteration 367: loss=7528.80
# Iteration 368: loss=7524.74
# Iteration 369: loss=7520.70
# Iteration 370: loss=7516.69
# Iteration 371: loss=7512.69
# Iteration 372: loss=7508.70
# Iteration 373: loss=7504.73
# Iteration 374: loss=7500.79
# Iteration 375: loss=7496.86
# Iteration 376: loss=7492.95
# Iteration 377: loss=7489.05
# Iteration 378: loss=7485.18
# Iteration 379: loss=7481.32
# Iteration 380: loss=7477.47
# Iteration 381: loss=7473.65
# Iteration 382: loss=7469.83
# Iteration 383: loss=7466.03
# Iteration 384: loss=7462.25
# Iteration 385: loss=7458.49
# Iteration 386: loss=7454.75
# Iteration 387: loss=7451.02
# Iteration 388: loss=7447.30
# Iteration 389: loss=7443.60
# Iteration 390: loss=7439.92
# Iteration 391: loss=7436.26
# Iteration 392: loss=7432.61
# Iteration 393: loss=7428.98
# Iteration 394: loss=7425.36
# Iteration 395: loss=7421.76
# Iteration 396: loss=7418.15
# Iteration 397: loss=7414.58
# Iteration 398: loss=7411.02
# Iteration 399: loss=7407.48
# Iteration 400: loss=7403.94
# Iteration 401: loss=7400.43
# Iteration 402: loss=7396.92
# Iteration 403: loss=7393.43
# Iteration 404: loss=7389.96
# Iteration 405: loss=7386.49
# Iteration 406: loss=7383.04
# Iteration 407: loss=7379.60
# Iteration 408: loss=7376.18
# Iteration 409: loss=7372.78
# Iteration 410: loss=7369.38
# Iteration 411: loss=7366.00
# Iteration 412: loss=7362.63
# Iteration 413: loss=7359.28
# Iteration 414: loss=7355.93
# Iteration 415: loss=7352.61
# Iteration 416: loss=7349.29
# Iteration 417: loss=7345.99
# Iteration 418: loss=7342.69
# Iteration 419: loss=7339.40
# Iteration 420: loss=7336.13
# Iteration 421: loss=7332.88
# Iteration 422: loss=7329.64
# Iteration 423: loss=7326.41
# Iteration 424: loss=7323.19
# Iteration 425: loss=7319.97
# Iteration 426: loss=7316.78
# Iteration 427: loss=7313.60
# Iteration 428: loss=7310.43
# Iteration 429: loss=7307.27
# Iteration 430: loss=7304.11
# Iteration 431: loss=7300.98
# Iteration 432: loss=7297.85
# Iteration 433: loss=7294.74
# Iteration 434: loss=7291.63
# Iteration 435: loss=7288.54
# Iteration 436: loss=7285.46
# Iteration 437: loss=7282.39
# Iteration 438: loss=7279.33
# Iteration 439: loss=7276.28
# Iteration 440: loss=7273.24
# Iteration 441: loss=7270.21
# Iteration 442: loss=7267.18
# Iteration 443: loss=7264.17
# Iteration 444: loss=7261.16
# Iteration 445: loss=7258.17
# Iteration 446: loss=7255.20
# Iteration 447: loss=7252.22
# Iteration 448: loss=7249.27
# Iteration 449: loss=7246.31
# Iteration 450: loss=7243.37
# Iteration 451: loss=7240.43
# Iteration 452: loss=7237.50
# Iteration 453: loss=7234.59
# Iteration 454: loss=7231.68
# Iteration 455: loss=7228.79
# Iteration 456: loss=7225.89
# Iteration 457: loss=7223.02
# Iteration 458: loss=7220.14
# Iteration 459: loss=7217.28
# Iteration 460: loss=7214.43
# Iteration 461: loss=7211.59
# Iteration 462: loss=7208.75
# Iteration 463: loss=7205.94
# Iteration 464: loss=7203.13
# Iteration 465: loss=7200.33
# Iteration 466: loss=7197.54
# Iteration 467: loss=7194.75
# Iteration 468: loss=7191.99
# Iteration 469: loss=7189.23
# Iteration 470: loss=7186.48
# Iteration 471: loss=7183.73
# Iteration 472: loss=7180.99
# Iteration 473: loss=7178.27
# Iteration 474: loss=7175.55
# Iteration 475: loss=7172.84
# Iteration 476: loss=7170.14
# Iteration 477: loss=7167.45
# Iteration 478: loss=7164.76
# Iteration 479: loss=7162.09
# Iteration 480: loss=7159.42
# Iteration 481: loss=7156.77
# Iteration 482: loss=7154.12
# Iteration 483: loss=7151.49
# Iteration 484: loss=7148.86
# Iteration 485: loss=7146.24
# Iteration 486: loss=7143.63
# Iteration 487: loss=7141.03
# Iteration 488: loss=7138.44
# Iteration 489: loss=7135.86
# Iteration 490: loss=7133.29
# Iteration 491: loss=7130.73
# Iteration 492: loss=7128.17
# Iteration 493: loss=7125.63
# Iteration 494: loss=7123.09
# Iteration 495: loss=7120.55
# Iteration 496: loss=7118.02
# Iteration 497: loss=7115.51
# Iteration 498: loss=7112.99
# Iteration 499: loss=7110.49

# %% [markdown]
# # Pour aller plus loin
#
# - modifier le ratio entre style et contenu pour obtenir une image plus fidele au contenu ou au style
# - testez avec vos propres images !
